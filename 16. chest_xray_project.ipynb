# %% [markdown]
# ### Step 1. 실험환경 Set-up
# Batch size, Epoch 등을 변경

# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수
BATCH_SIZE = 20

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 40

# %% [markdown]
# ### Step 2. 데이터 준비하기
# 원본 데이터를 가져와서 전처리 및 배치 구성을 진행합니다.
# 의료영상 이미지의 특성상 데이터는 언제나 충분하지 않습니다. 이를 극복할 수 있는 방법을 고민해 봅시다.
#
# 이전 실습에서 고려하지 않았던 augmentation 기법을 고려해 볼 수 있을 것입니다. 그러나 의료영상인 경우, 일반적인 이미지처리에서 사용하는 augmentation들이 항상 도움이 된다고 말할 수 없습니다. 특히 X-RAY 같은 의료영상의 특성상, 육안으로도 구분하기 어려운 미묘한 차이에 더해진 노이즈 등 부수효과가 오히려 방해를 줄 수도 있기 때문입니다.
# 그래서 augmentation 도입은 신중해야 합니다.
#
# 만약 예를 들어 좌우반전 정도의 augmentation만 도입한다고 한다면 다음과 같이 진행될 것입니다.

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

# 정상 이미지 수와 폐렴 이미지 수 확인
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])

# tf.data 인스턴스
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# train 데이터셋, validation 데이터셋 수
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()

# 라벨 이름
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])

# 라벨 데이터 만들어주는 함수
def get_label(file_path):
    http://localhost:8889/notebooks/aiffel/Exploration/22.%20%EC%9D%98%EB%A3%8C%20%EC%98%81%EC%83%81%20%EB%B6%84%EC%84%9D/2.%20%ED%8F%90%EB%A0%B4%20%EC%A7%84%EB%8B%A8%EA%B8%B0%20%EC%84%B1%EB%8A%A5%20%EA%B0%9C%EC%84%A0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-Copy1.ipynb#parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# test 데이터 셋 생성
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

# %% [markdown]
# #### Data Augment

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ### Step 3. 데이터 시각화
# 학습용 데이터를 시각화해서 확인해 봅니다.
# 만약 augmentation을 시도했다면 이후 실습코드에 있는 show_batch() 함수를 통해 실제로 좌우반전 등이 제대로 처리되었는지 확인해 봅시다.

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ### Step 4. CNN 모델링
# 의료영상 판독을 위해 실습에서 구현했던 model에서 다양한 것들을 바꾸어 가며 실험해볼 수 있습니다. Convolution filter, 채널 개수, activation, 모델구조 등을 다양하게 바꾸어볼 수 있습니다.
#
# 그리고, 우리는 BatchNormalization과 Dropout을 한 모델 안에서 동시에 사용하는 특이한 구성을 실습했습니다.
# 이것은 일반적으로 잘 사용되는 형태는 아닙니다. 하지만 이미지 사이즈가 크고 데이터가 부족한 의료영상에서는 실용적으로 간혹 좋은 성능을 보이기도 합니다. 만약 이 구성을 변경해 보면 어떤 효과가 발생하는지도 실험해 봅시다. BatchNormalization을 쓰거나 혹은 쓰지 않거나, Dropout을 쓰거나 혹은 쓰지 않거나 할 수 있습니다. 또, Dropout 비율을 변경해볼 수도 있습니다.

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ### Step 5. 데이터 imbalance 처리
# 실습코드에서 데이터의 imbalance 문제에 대처하기 위해 데이터 비율로 나누어진 class_weight를 설정해 주었습니다. 만약 이러한 처리를 생략한다면 어떻게 될까요? 또 recall을 강조하기 위해 폐렴데이터를 잘 맞추는 것을 더 강화하는 효과를 만들어낼 수는 없을까요?

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.94
# Weight for class 1: 0.67

# %% [markdown]
# ### Step 6. 모델 훈련
# loss 함수를 변경하기는 어렵겠지만, optimizer나 learning rate 등의 변화를 고려해볼 수 있을 것입니다.

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )
    
# 모델 fit
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/40
# 209/209 [==============================] - 21s 103ms/step - loss: 0.4106 - accuracy: 0.8213 - precision: 0.9492 - recall: 0.8019 - val_loss: 0.5784 - val_accuracy: 0.7442 - val_precision: 0.7442 - val_recall: 1.0000
# Epoch 2/40
# 209/209 [==============================] - 22s 106ms/step - loss: 0.2406 - accuracy: 0.9072 - precision: 0.9689 - recall: 0.9040 - val_loss: 0.8204 - val_accuracy: 0.7433 - val_precision: 0.7433 - val_recall: 1.0000
# Epoch 3/40
# 209/209 [==============================] - 22s 105ms/step - loss: 0.2045 - accuracy: 0.9256 - precision: 0.9738 - recall: 0.9245 - val_loss: 0.6640 - val_accuracy: 0.7433 - val_precision: 0.7433 - val_recall: 1.0000
# Epoch 4/40
# 209/209 [==============================] - 22s 104ms/step - loss: 0.1866 - accuracy: 0.9285 - precision: 0.9778 - recall: 0.9245 - val_loss: 0.2566 - val_accuracy: 0.8548 - val_precision: 0.8364 - val_recall: 1.0000
# Epoch 5/40
# 209/209 [==============================] - 22s 104ms/step - loss: 0.1618 - accuracy: 0.9409 - precision: 0.9824 - recall: 0.9371 - val_loss: 1.2422 - val_accuracy: 0.6702 - val_precision: 0.9977 - val_recall: 0.5598
# Epoch 6/40
# 209/209 [==============================] - 21s 100ms/step - loss: 0.1631 - accuracy: 0.9356 - precision: 0.9781 - recall: 0.9343 - val_loss: 0.2063 - val_accuracy: 0.9192 - val_precision: 1.0000 - val_recall: 0.8916
# Epoch 7/40
# 209/209 [==============================] - 21s 101ms/step - loss: 0.1486 - accuracy: 0.9450 - precision: 0.9828 - recall: 0.9423 - val_loss: 0.0699 - val_accuracy: 0.9731 - val_precision: 0.9807 - val_recall: 0.9832
# Epoch 8/40
# 209/209 [==============================] - 21s 102ms/step - loss: 0.1544 - accuracy: 0.9464 - precision: 0.9822 - recall: 0.9447 - val_loss: 0.1944 - val_accuracy: 0.9317 - val_precision: 1.0000 - val_recall: 0.9083
# Epoch 9/40
# 209/209 [==============================] - 21s 102ms/step - loss: 0.1273 - accuracy: 0.9531 - precision: 0.9869 - recall: 0.9494 - val_loss: 0.2506 - val_accuracy: 0.9019 - val_precision: 0.9985 - val_recall: 0.8698
# Epoch 10/40
# 209/209 [==============================] - 22s 104ms/step - loss: 0.1322 - accuracy: 0.9522 - precision: 0.9850 - recall: 0.9500 - val_loss: 0.0602 - val_accuracy: 0.9769 - val_precision: 0.9820 - val_recall: 0.9871
# Epoch 11/40
# 209/209 [==============================] - 21s 99ms/step - loss: 0.1150 - accuracy: 0.9531 - precision: 0.9869 - recall: 0.9494 - val_loss: 0.0505 - val_accuracy: 0.9798 - val_precision: 0.9858 - val_recall: 0.9870
# Epoch 12/40
# 209/209 [==============================] - 21s 100ms/step - loss: 0.1069 - accuracy: 0.9612 - precision: 0.9874 - recall: 0.9599 - val_loss: 0.0749 - val_accuracy: 0.9740 - val_precision: 0.9807 - val_recall: 0.9845
# Epoch 13/40
# 209/209 [==============================] - 21s 103ms/step - loss: 0.1373 - accuracy: 0.9500 - precision: 0.9823 - recall: 0.9497 - val_loss: 0.0799 - val_accuracy: 0.9702 - val_precision: 0.9881 - val_recall: 0.9715
# Epoch 14/40
# 209/209 [==============================] - 22s 103ms/step - loss: 0.1112 - accuracy: 0.9572 - precision: 0.9867 - recall: 0.9552 - val_loss: 0.0649 - val_accuracy: 0.9702 - val_precision: 0.9882 - val_recall: 0.9716
# Epoch 15/40
# 209/209 [==============================] - 21s 103ms/step - loss: 0.1090 - accuracy: 0.9627 - precision: 0.9893 - recall: 0.9599 - val_loss: 0.0771 - val_accuracy: 0.9731 - val_precision: 0.9908 - val_recall: 0.9729
# Epoch 16/40
# 209/209 [==============================] - 22s 107ms/step - loss: 0.1094 - accuracy: 0.9598 - precision: 0.9887 - recall: 0.9569 - val_loss: 0.1223 - val_accuracy: 0.9558 - val_precision: 0.9932 - val_recall: 0.9470
# Epoch 17/40
# 209/209 [==============================] - 22s 105ms/step - loss: 0.0849 - accuracy: 0.9691 - precision: 0.9920 - recall: 0.9661 - val_loss: 0.1746 - val_accuracy: 0.9240 - val_precision: 1.0000 - val_recall: 0.8979
# Epoch 18/40
# 209/209 [==============================] - 21s 101ms/step - loss: 0.1046 - accuracy: 0.9634 - precision: 0.9891 - recall: 0.9613 - val_loss: 0.2625 - val_accuracy: 0.8856 - val_precision: 1.0000 - val_recall: 0.8465
# Epoch 19/40
# 209/209 [==============================] - 22s 104ms/step - loss: 0.0812 - accuracy: 0.9682 - precision: 0.9933 - recall: 0.9635 - val_loss: 0.1297 - val_accuracy: 0.9529 - val_precision: 0.9973 - val_recall: 0.9393
# Epoch 20/40
# 209/209 [==============================] - 21s 102ms/step - loss: 0.0842 - accuracy: 0.9675 - precision: 0.9911 - recall: 0.9649 - val_loss: 0.0505 - val_accuracy: 0.9808 - val_precision: 0.9845 - val_recall: 0.9896
# Epoch 21/40
# 209/209 [==============================] - 21s 102ms/step - loss: 0.0735 - accuracy: 0.9734 - precision: 0.9934 - recall: 0.9706 - val_loss: 0.0938 - val_accuracy: 0.9673 - val_precision: 0.9907 - val_recall: 0.9650
# Epoch 22/40
# 209/209 [==============================] - 21s 102ms/step - loss: 0.0820 - accuracy: 0.9682 - precision: 0.9924 - recall: 0.9646 - val_loss: 0.0706 - val_accuracy: 0.9798 - val_precision: 0.9759 - val_recall: 0.9974
# Epoch 23/40
# 209/209 [==============================] - 22s 104ms/step - loss: 0.0832 - accuracy: 0.9689 - precision: 0.9917 - recall: 0.9661 - val_loss: 0.0627 - val_accuracy: 0.9798 - val_precision: 0.9821 - val_recall: 0.9910
# Epoch 24/40
# 209/209 [==============================] - 22s 103ms/step - loss: 0.0744 - accuracy: 0.9720 - precision: 0.9931 - recall: 0.9691 - val_loss: 0.0552 - val_accuracy: 0.9769 - val_precision: 0.9934 - val_recall: 0.9754
# Epoch 25/40
# 209/209 [==============================] - 21s 102ms/step - loss: 0.0670 - accuracy: 0.9763 - precision: 0.9950 - recall: 0.9729 - val_loss: 0.0937 - val_accuracy: 0.9606 - val_precision: 1.0000 - val_recall: 0.9471
# Epoch 26/40
# 209/209 [==============================] - 22s 103ms/step - loss: 0.0839 - accuracy: 0.9701 - precision: 0.9918 - recall: 0.9678 - val_loss: 0.0430 - val_accuracy: 0.9817 - val_precision: 0.9896 - val_recall: 0.9858
# Epoch 27/40
# 209/209 [==============================] - 21s 102ms/step - loss: 0.0623 - accuracy: 0.9766 - precision: 0.9941 - recall: 0.9742 - val_loss: 0.2273 - val_accuracy: 0.9385 - val_precision: 0.9784 - val_recall: 0.9380
# Epoch 28/40
# 209/209 [==============================] - 22s 103ms/step - loss: 0.0961 - accuracy: 0.9665 - precision: 0.9933 - recall: 0.9613 - val_loss: 0.0761 - val_accuracy: 0.9769 - val_precision: 0.9747 - val_recall: 0.9948
# Epoch 29/40
# 209/209 [==============================] - 21s 102ms/step - loss: 0.0688 - accuracy: 0.9703 - precision: 0.9927 - recall: 0.9670 - val_loss: 0.0821 - val_accuracy: 0.9683 - val_precision: 0.9946 - val_recall: 0.9624
# Epoch 30/40
# 209/209 [==============================] - 22s 105ms/step - loss: 0.0525 - accuracy: 0.9809 - precision: 0.9970 - recall: 0.9771 - val_loss: 0.1572 - val_accuracy: 0.9615 - val_precision: 0.9519 - val_recall: 0.9987
# Epoch 31/40
# 209/209 [==============================] - 22s 103ms/step - loss: 0.0722 - accuracy: 0.9715 - precision: 0.9927 - recall: 0.9687 - val_loss: 0.1860 - val_accuracy: 0.9462 - val_precision: 0.9356 - val_recall: 0.9961
# Epoch 32/40
# 209/209 [==============================] - 21s 102ms/step - loss: 0.0606 - accuracy: 0.9785 - precision: 0.9954 - recall: 0.9756 - val_loss: 0.0614 - val_accuracy: 0.9817 - val_precision: 0.9821 - val_recall: 0.9935
# Epoch 33/40
# 209/209 [==============================] - 22s 103ms/step - loss: 0.0576 - accuracy: 0.9792 - precision: 0.9957 - recall: 0.9762 - val_loss: 0.0570 - val_accuracy: 0.9779 - val_precision: 0.9934 - val_recall: 0.9767
# Epoch 34/40
# 209/209 [==============================] - 22s 103ms/step - loss: 0.0606 - accuracy: 0.9780 - precision: 0.9954 - recall: 0.9749 - val_loss: 0.0548 - val_accuracy: 0.9769 - val_precision: 0.9960 - val_recall: 0.9728
# Epoch 35/40
# 209/209 [==============================] - 22s 104ms/step - loss: 0.0523 - accuracy: 0.9809 - precision: 0.9954 - recall: 0.9786 - val_loss: 0.0531 - val_accuracy: 0.9779 - val_precision: 0.9987 - val_recall: 0.9715
# Epoch 36/40
# 209/209 [==============================] - 22s 104ms/step - loss: 0.0505 - accuracy: 0.9797 - precision: 0.9961 - recall: 0.9765 - val_loss: 0.0557 - val_accuracy: 0.9788 - val_precision: 0.9858 - val_recall: 0.9858
# Epoch 37/40
# 209/209 [==============================] - 21s 101ms/step - loss: 0.0428 - accuracy: 0.9830 - precision: 0.9957 - recall: 0.9813 - val_loss: 0.0699 - val_accuracy: 0.9692 - val_precision: 0.9973 - val_recall: 0.9614
# Epoch 38/40
# 209/209 [==============================] - 21s 101ms/step - loss: 0.0498 - accuracy: 0.9811 - precision: 0.9964 - recall: 0.9781 - val_loss: 0.0663 - val_accuracy: 0.9779 - val_precision: 0.9772 - val_recall: 0.9935
# Epoch 39/40
# 209/209 [==============================] - 21s 102ms/step - loss: 0.0523 - accuracy: 0.9828 - precision: 0.9964 - recall: 0.9804 - val_loss: 0.0699 - val_accuracy: 0.9760 - val_precision: 0.9947 - val_recall: 0.9729
# Epoch 40/40
# 209/209 [==============================] - 21s 101ms/step - loss: 0.0555 - accuracy: 0.9789 - precision: 0.9967 - recall: 0.9748 - val_loss: 0.0757 - val_accuracy: 0.9712 - val_precision: 1.0000 - val_recall: 0.9612

# %% [markdown]
# ### Step 7. 결과 확인과 시각화
# 테스트데이터로 훈련된 모델을 평가해 봅시다. 우선은 accuracy를 고려해야겠지만 의료영상 모델의 특성상 recall도 중요합니다. 훈련과정의 history 그래프를 시각화해 보고, 학습 진행양상을 면밀히 분석해 보는 것도 잊지 않도록 합시다.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
    
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 32/32 [==============================] - 7s 210ms/step - loss: 0.8771 - accuracy: 0.8205 - precision: 0.7872 - recall: 0.9769

# %% [markdown]
# ### Report
# 좌우 반전 augment를 적용한 기본 모델의 정확도는 0.82 입니다.
