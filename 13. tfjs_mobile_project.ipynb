# %% [markdown]
# ## 프로젝트: Face2Emoji 모바일 웹앱

# %% [markdown]
# ### Step 1. 표정 데이터로 MobileNet 학습하기

# %%
import numpy as np
import tqdm
import os

train_x = []
train_y = []
eval_x = []
eval_y = []

csv_path = os.getenv('HOME')+'/aiffel/tfjs_mobile/data/fer2013.csv'

with open(csv_path) as f:
  for line in tqdm.tqdm(f.read().splitlines()[1:]):
    emotion, pixels, usage = line.split(',')
    
    x = np.array(pixels.split(' ')).astype(float).reshape(48, 48, 1) / 255
    y = int(emotion)

    if usage == 'PrivateTest':
      eval_x.append(x)
      eval_y.append(y)
    else:
      train_x.append(x)
      train_y.append(y)

print('train : {}, eval :{}'.format(len(train_x), len(eval_x)))
# Out:
# 100%|██████████| 35887/35887 [00:25<00:00, 1418.07it/s]
# train : 32298, eval :3589

# %%
from matplotlib import pyplot as plt

LABELS = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

print(LABELS[train_y[0]])
plt.imshow(train_x[0].reshape([48, 48]), cmap='gray')
# Out:
# Angry

# %%
import tensorflow as tf

# model 선언 
model = tf.keras.applications.MobileNetV2(input_shape=(48, 48, 1), weights=None, classes=7)

# model.compile
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.CategoricalAccuracy()])

#model.fit
model.fit(np.stack(train_x),
          tf.keras.utils.to_categorical(train_y),
          epochs=100,
          batch_size=512,
          validation_data=(np.stack(eval_x),
                           tf.keras.utils.to_categorical(eval_y)))
# Out:
# Epoch 1/100
# 64/64 [==============================] - 67s 1s/step - loss: 1.8412 - categorical_accuracy: 0.2425 - val_loss: 1.9292 - val_categorical_accuracy: 0.2449
# Epoch 2/100
# 64/64 [==============================] - 69s 1s/step - loss: 1.6861 - categorical_accuracy: 0.3243 - val_loss: 1.9231 - val_categorical_accuracy: 0.2449
# Epoch 3/100
# 64/64 [==============================] - 65s 1s/step - loss: 1.5738 - categorical_accuracy: 0.3824 - val_loss: 1.9161 - val_categorical_accuracy: 0.2449
# Epoch 4/100
# 64/64 [==============================] - 64s 1s/step - loss: 1.4722 - categorical_accuracy: 0.4309 - val_loss: 1.9088 - val_categorical_accuracy: 0.2449
# Epoch 5/100
# 64/64 [==============================] - 64s 998ms/step - loss: 1.4019 - categorical_accuracy: 0.4628 - val_loss: 1.9072 - val_categorical_accuracy: 0.1471
# Epoch 6/100
# 64/64 [==============================] - 64s 998ms/step - loss: 1.3292 - categorical_accuracy: 0.4956 - val_loss: 1.9049 - val_categorical_accuracy: 0.1368
# Epoch 7/100
# 64/64 [==============================] - 65s 1s/step - loss: 1.2588 - categorical_accuracy: 0.5230 - val_loss: 1.8973 - val_categorical_accuracy: 0.1368
# Epoch 8/100
# 64/64 [==============================] - 65s 1s/step - loss: 1.2004 - categorical_accuracy: 0.5503 - val_loss: 1.8955 - val_categorical_accuracy: 0.1368
# Epoch 9/100
# 64/64 [==============================] - 65s 1s/step - loss: 1.1211 - categorical_accuracy: 0.5800 - val_loss: 1.8914 - val_categorical_accuracy: 0.1368
# Epoch 10/100
# 64/64 [==============================] - 67s 1s/step - loss: 1.0772 - categorical_accuracy: 0.6019 - val_loss: 1.9037 - val_categorical_accuracy: 0.1368
# Epoch 11/100
# 64/64 [==============================] - 64s 993ms/step - loss: 0.9980 - categorical_accuracy: 0.6325 - val_loss: 1.9038 - val_categorical_accuracy: 0.1368
# Epoch 12/100
# 64/64 [==============================] - 64s 995ms/step - loss: 0.9481 - categorical_accuracy: 0.6534 - val_loss: 1.9159 - val_categorical_accuracy: 0.1368
# Epoch 13/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.9348 - categorical_accuracy: 0.6587 - val_loss: 1.9245 - val_categorical_accuracy: 0.1368
# Epoch 14/100
# 64/64 [==============================] - 64s 1s/step - loss: 0.8198 - categorical_accuracy: 0.7018 - val_loss: 1.9435 - val_categorical_accuracy: 0.1368
# Epoch 15/100
# 64/64 [==============================] - 64s 1000ms/step - loss: 0.7709 - categorical_accuracy: 0.7198 - val_loss: 1.9530 - val_categorical_accuracy: 0.1655
# Epoch 16/100
# 64/64 [==============================] - 63s 989ms/step - loss: 0.7400 - categorical_accuracy: 0.7322 - val_loss: 1.9642 - val_categorical_accuracy: 0.1655
# Epoch 17/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.6725 - categorical_accuracy: 0.7567 - val_loss: 1.9850 - val_categorical_accuracy: 0.1655
# Epoch 18/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.6357 - categorical_accuracy: 0.7720 - val_loss: 2.0037 - val_categorical_accuracy: 0.1655
# Epoch 19/100
# 64/64 [==============================] - 64s 1s/step - loss: 0.6201 - categorical_accuracy: 0.7785 - val_loss: 2.0100 - val_categorical_accuracy: 0.1655
# Epoch 20/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.5517 - categorical_accuracy: 0.8008 - val_loss: 2.0294 - val_categorical_accuracy: 0.1655
# Epoch 21/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.5183 - categorical_accuracy: 0.8120 - val_loss: 2.0504 - val_categorical_accuracy: 0.1655
# Epoch 22/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.4917 - categorical_accuracy: 0.8226 - val_loss: 2.0528 - val_categorical_accuracy: 0.1655
# Epoch 23/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.4134 - categorical_accuracy: 0.8519 - val_loss: 2.0880 - val_categorical_accuracy: 0.1655
# Epoch 24/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.4322 - categorical_accuracy: 0.8449 - val_loss: 2.1150 - val_categorical_accuracy: 0.1655
# Epoch 25/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.4175 - categorical_accuracy: 0.8503 - val_loss: 2.0923 - val_categorical_accuracy: 0.1655
# Epoch 26/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.3926 - categorical_accuracy: 0.8595 - val_loss: 2.1231 - val_categorical_accuracy: 0.1655
# Epoch 27/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.3348 - categorical_accuracy: 0.8811 - val_loss: 2.1628 - val_categorical_accuracy: 0.1655
# Epoch 28/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.3404 - categorical_accuracy: 0.8798 - val_loss: 2.1509 - val_categorical_accuracy: 0.1655
# Epoch 29/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.2923 - categorical_accuracy: 0.8980 - val_loss: 2.1695 - val_categorical_accuracy: 0.1655
# Epoch 30/100
# 64/64 [==============================] - 63s 981ms/step - loss: 0.3603 - categorical_accuracy: 0.8734 - val_loss: 2.1826 - val_categorical_accuracy: 0.1368
# Epoch 31/100
# 64/64 [==============================] - 64s 1s/step - loss: 0.2897 - categorical_accuracy: 0.8990 - val_loss: 2.2124 - val_categorical_accuracy: 0.1655
# Epoch 32/100
# 64/64 [==============================] - 63s 987ms/step - loss: 0.2527 - categorical_accuracy: 0.9105 - val_loss: 2.1876 - val_categorical_accuracy: 0.1655
# Epoch 33/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.3601 - categorical_accuracy: 0.8729 - val_loss: 2.2595 - val_categorical_accuracy: 0.1655
# Epoch 34/100
# 64/64 [==============================] - 68s 1s/step - loss: 0.2066 - categorical_accuracy: 0.9272 - val_loss: 2.2537 - val_categorical_accuracy: 0.1655
# Epoch 35/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.3195 - categorical_accuracy: 0.8875 - val_loss: 2.2825 - val_categorical_accuracy: 0.1655
# Epoch 36/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.2364 - categorical_accuracy: 0.9149 - val_loss: 2.2995 - val_categorical_accuracy: 0.1655
# Epoch 37/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.2249 - categorical_accuracy: 0.9206 - val_loss: 2.3147 - val_categorical_accuracy: 0.1655
# Epoch 38/100
# 64/64 [==============================] - 70s 1s/step - loss: 0.2026 - categorical_accuracy: 0.9298 - val_loss: 2.3218 - val_categorical_accuracy: 0.1655
# Epoch 39/100
# 64/64 [==============================] - 68s 1s/step - loss: 0.2913 - categorical_accuracy: 0.8984 - val_loss: 2.3848 - val_categorical_accuracy: 0.1655
# Epoch 40/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.1704 - categorical_accuracy: 0.9407 - val_loss: 2.3987 - val_categorical_accuracy: 0.1655
# Epoch 41/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1597 - categorical_accuracy: 0.9450 - val_loss: 2.4500 - val_categorical_accuracy: 0.1655
# Epoch 42/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.2529 - categorical_accuracy: 0.9111 - val_loss: 2.4481 - val_categorical_accuracy: 0.1368
# Epoch 43/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.1810 - categorical_accuracy: 0.9370 - val_loss: 2.3933 - val_categorical_accuracy: 0.1655
# Epoch 44/100
# 64/64 [==============================] - 63s 992ms/step - loss: 0.1382 - categorical_accuracy: 0.9529 - val_loss: 2.4493 - val_categorical_accuracy: 0.1655
# Epoch 45/100
# 64/64 [==============================] - 63s 989ms/step - loss: 0.1228 - categorical_accuracy: 0.9588 - val_loss: 2.5271 - val_categorical_accuracy: 0.1655
# Epoch 46/100
# 64/64 [==============================] - 64s 1s/step - loss: 0.1898 - categorical_accuracy: 0.9340 - val_loss: 2.4107 - val_categorical_accuracy: 0.1655
# Epoch 47/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.1462 - categorical_accuracy: 0.9504 - val_loss: 2.4266 - val_categorical_accuracy: 0.1368
# Epoch 48/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.1621 - categorical_accuracy: 0.9442 - val_loss: 2.4900 - val_categorical_accuracy: 0.1365
# Epoch 49/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.2521 - categorical_accuracy: 0.9119 - val_loss: 2.4669 - val_categorical_accuracy: 0.1368
# Epoch 50/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1596 - categorical_accuracy: 0.9447 - val_loss: 2.6048 - val_categorical_accuracy: 0.1368
# Epoch 51/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1313 - categorical_accuracy: 0.9559 - val_loss: 2.6287 - val_categorical_accuracy: 0.1655
# Epoch 52/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1646 - categorical_accuracy: 0.9435 - val_loss: 2.6820 - val_categorical_accuracy: 0.1574
# Epoch 53/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1220 - categorical_accuracy: 0.9582 - val_loss: 2.7109 - val_categorical_accuracy: 0.1658
# Epoch 54/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.1452 - categorical_accuracy: 0.9496 - val_loss: 2.7061 - val_categorical_accuracy: 0.1368
# Epoch 55/100
# 64/64 [==============================] - 64s 1s/step - loss: 0.2623 - categorical_accuracy: 0.9094 - val_loss: 2.7207 - val_categorical_accuracy: 0.1385
# Epoch 56/100
# 64/64 [==============================] - 62s 974ms/step - loss: 0.1425 - categorical_accuracy: 0.9508 - val_loss: 2.7534 - val_categorical_accuracy: 0.1655
# Epoch 57/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1302 - categorical_accuracy: 0.9554 - val_loss: 2.8055 - val_categorical_accuracy: 0.1638
# Epoch 58/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1146 - categorical_accuracy: 0.9620 - val_loss: 2.8138 - val_categorical_accuracy: 0.1655
# Epoch 59/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.1179 - categorical_accuracy: 0.9592 - val_loss: 3.0669 - val_categorical_accuracy: 0.1655
# Epoch 60/100
# 64/64 [==============================] - 62s 973ms/step - loss: 0.1190 - categorical_accuracy: 0.9581 - val_loss: 3.0561 - val_categorical_accuracy: 0.1647
# Epoch 61/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1858 - categorical_accuracy: 0.9353 - val_loss: 3.0961 - val_categorical_accuracy: 0.1655
# Epoch 62/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1514 - categorical_accuracy: 0.9480 - val_loss: 3.1073 - val_categorical_accuracy: 0.1597
# Epoch 63/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1777 - categorical_accuracy: 0.9378 - val_loss: 2.7869 - val_categorical_accuracy: 0.1666
# Epoch 64/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1114 - categorical_accuracy: 0.9618 - val_loss: 3.1479 - val_categorical_accuracy: 0.1658
# Epoch 65/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1746 - categorical_accuracy: 0.9405 - val_loss: 3.2639 - val_categorical_accuracy: 0.1649
# Epoch 66/100
# 64/64 [==============================] - 64s 995ms/step - loss: 0.1633 - categorical_accuracy: 0.9446 - val_loss: 3.4047 - val_categorical_accuracy: 0.1663
# Epoch 67/100
# 64/64 [==============================] - 64s 999ms/step - loss: 0.0974 - categorical_accuracy: 0.9668 - val_loss: 3.4847 - val_categorical_accuracy: 0.1658
# Epoch 68/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.0932 - categorical_accuracy: 0.9690 - val_loss: 3.5722 - val_categorical_accuracy: 0.1666
# Epoch 69/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.1664 - categorical_accuracy: 0.9448 - val_loss: 3.6657 - val_categorical_accuracy: 0.1714
# Epoch 70/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.1888 - categorical_accuracy: 0.9349 - val_loss: 3.4645 - val_categorical_accuracy: 0.1789
# Epoch 71/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.1685 - categorical_accuracy: 0.9436 - val_loss: 3.4803 - val_categorical_accuracy: 0.1836
# Epoch 72/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.0715 - categorical_accuracy: 0.9761 - val_loss: 3.7494 - val_categorical_accuracy: 0.1928
# Epoch 73/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.0682 - categorical_accuracy: 0.9760 - val_loss: 3.5836 - val_categorical_accuracy: 0.2165
# Epoch 74/100
# 64/64 [==============================] - 64s 992ms/step - loss: 0.1610 - categorical_accuracy: 0.9459 - val_loss: 3.4872 - val_categorical_accuracy: 0.2118
# Epoch 75/100
# 64/64 [==============================] - 64s 995ms/step - loss: 0.1677 - categorical_accuracy: 0.9416 - val_loss: 3.5892 - val_categorical_accuracy: 0.2522
# Epoch 76/100
# 64/64 [==============================] - 65s 1s/step - loss: 0.1109 - categorical_accuracy: 0.9616 - val_loss: 3.2715 - val_categorical_accuracy: 0.2845
# Epoch 77/100
# 64/64 [==============================] - 68s 1s/step - loss: 0.1765 - categorical_accuracy: 0.9380 - val_loss: 3.7948 - val_categorical_accuracy: 0.2575
# Epoch 78/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1510 - categorical_accuracy: 0.9488 - val_loss: 3.7241 - val_categorical_accuracy: 0.2920
# Epoch 79/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.0990 - categorical_accuracy: 0.9654 - val_loss: 3.5393 - val_categorical_accuracy: 0.3162
# Epoch 80/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1229 - categorical_accuracy: 0.9577 - val_loss: 3.3905 - val_categorical_accuracy: 0.3564
# Epoch 81/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1678 - categorical_accuracy: 0.9419 - val_loss: 3.2587 - val_categorical_accuracy: 0.3728
# Epoch 82/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1454 - categorical_accuracy: 0.9505 - val_loss: 3.3505 - val_categorical_accuracy: 0.3628
# Epoch 83/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.0584 - categorical_accuracy: 0.9811 - val_loss: 3.8087 - val_categorical_accuracy: 0.3753
# Epoch 84/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0669 - categorical_accuracy: 0.9768 - val_loss: 3.7873 - val_categorical_accuracy: 0.3642
# Epoch 85/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0961 - categorical_accuracy: 0.9664 - val_loss: 3.7546 - val_categorical_accuracy: 0.3689
# Epoch 86/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0714 - categorical_accuracy: 0.9762 - val_loss: 3.7821 - val_categorical_accuracy: 0.3920
# Epoch 87/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0831 - categorical_accuracy: 0.9708 - val_loss: 3.7173 - val_categorical_accuracy: 0.4218
# Epoch 88/100
# 64/64 [==============================] - 67s 1s/step - loss: 0.1049 - categorical_accuracy: 0.9631 - val_loss: 3.9503 - val_categorical_accuracy: 0.4224
# Epoch 89/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0742 - categorical_accuracy: 0.9739 - val_loss: 4.1778 - val_categorical_accuracy: 0.4316
# Epoch 90/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0783 - categorical_accuracy: 0.9736 - val_loss: 4.0582 - val_categorical_accuracy: 0.4327
# Epoch 91/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1341 - categorical_accuracy: 0.9564 - val_loss: 4.9142 - val_categorical_accuracy: 0.4213
# Epoch 92/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1300 - categorical_accuracy: 0.9544 - val_loss: 4.7050 - val_categorical_accuracy: 0.4241
# Epoch 93/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0819 - categorical_accuracy: 0.9723 - val_loss: 4.6090 - val_categorical_accuracy: 0.4383
# Epoch 94/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1028 - categorical_accuracy: 0.9654 - val_loss: 4.6964 - val_categorical_accuracy: 0.4168
# Epoch 95/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.1060 - categorical_accuracy: 0.9650 - val_loss: 5.0659 - val_categorical_accuracy: 0.4177
# Epoch 96/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0964 - categorical_accuracy: 0.9664 - val_loss: 4.7081 - val_categorical_accuracy: 0.4494
# Epoch 97/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0748 - categorical_accuracy: 0.9739 - val_loss: 4.6130 - val_categorical_accuracy: 0.4310
# Epoch 98/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0651 - categorical_accuracy: 0.9776 - val_loss: 5.0979 - val_categorical_accuracy: 0.4475
# Epoch 99/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0521 - categorical_accuracy: 0.9816 - val_loss: 5.2331 - val_categorical_accuracy: 0.4366
# Epoch 100/100
# 64/64 [==============================] - 66s 1s/step - loss: 0.0477 - categorical_accuracy: 0.9833 - val_loss: 4.9390 - val_categorical_accuracy: 0.4419

# %% [markdown]
# ### Step 2. 학습된 모델을 TensorFlow.js 형식으로 변환하기

# %%
import os
model_path = os.getenv('HOME')+'/aiffel/tfjs_mobile/model.h5'
model.save(model_path)

# %% [markdown]
# ### Step 3. 카메라에서 가져온 영상 전처리하기

# %%
<html>
  <head>
    <meta charset="utf-8">
    <meta name="viewport" content="width=device-width, user-scalable=yes, initial-scale=1, maximum-scale=1">
    <title>Demo</title>
    <script src="https://cdn.jsdelivr.net/npm/@tensorflow/tfjs@1.0.1"></script>
  </head>
  <body>
    <video playsinline autoplay></video>
    <button>Capture</button>
    <canvas></canvas>
    <span></span>
    <script>
      video = document.querySelector('video');
      canvas = document.querySelector('canvas');
      button = document.querySelector('button');
      canvas.width = 48;
      canvas.height = 48;
      canvas.style.filter = 'grayscale(1)';
      video.style.transform = 'scaleX(-1)';

      span = document.querySelector('span');
      span.style.fontSize = '48px';


      const LABELS = {
        0: '🤬', // angry
        1: '🤢', // disgust
        2: '😱', // fear
        3: '😄', // happy
        4: '😢', // sad
        5: '😲', // surprise
        6: '😐' // neutral
      }
      
      function classifyCallback(predictions) {
        alert(predictions[0].className + ':' + predictions[0].probabaility);
      }

      async function predict() {
        const model = await tf.loadLayersModel('./model/model.json');

        image = tf.browser.fromPixels(canvas);
        console.log(image);
        image = image.toFloat().mean(2).mul(1/255.0).reshape([-1, 48, 48, 1]);
        logits = model.predict(image);
        model.classify(image).then(predictions => {
          alert(predictions[0].className + ':' +
          predictions[0].probabaility);
        })
        const results = await logits.softmax().data();
        i = results.indexOf(Math.max(...results));

        image.dispose();
        logits.dispose();
        console.log(results);
        
        span.innerHTML = LABELS[i];
      }

      button.onclick = function() {
        w = video.videoWidth;
        h = video.videoHeight;
        s = Math.min(w, h);
        sx = (w-s)/2;
        sy = (h-s)/2;

        canvas.getContext('2d').drawImage(video, sx=sx, sy=sy, swidth=s,
          sheight=s, x=0, y=0, width=48, height=48);

        span.innerHTML = '⌛';
        predict();
    };


    constraints = {
      audio: false,
      video: true
    };

    function handleSuccess(stream) {
      video.srcObject = stream;
    }

    function handleError(error) {
      alert('navigator.MediaDevices.getUserMedia error: ' + error.message + error.name);
    }

    navigator.mediaDevices.getUserMedia(constraints).then(handleSuccess).catch(handleError);
</script>
  </body>
</html>

# %% [markdown]
# #### url
# https://jsw8050.github.io/tfjs_mobile/
